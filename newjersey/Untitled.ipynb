# %%
import pandas as pd
import zipfile
from datetime import datetime
pd.set_option('display.max_columns', None)

# %%
for year in range(2006,2017):
    # EXTRACT DATA FROM ZIPFILES
    extract_path = f"{year}"
    zip_path = f"NewJersey{year}Accidents.zip"
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    zip_path = f"NewJersey{year}Vehicles.zip"
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    zip_path = f"NewJersey{year}Drivers.zip"
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    zip_path = f"NewJersey{year}Occupants.zip"
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    zip_path = f"NewJersey{year}Pedestrians.zip"
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    # Comb person-level CSVs to get all injury crash IDs
    injuries = set()
    deaths = set()
    with open(f"{year}/NewJersey{year}Pedestrians.txt", 'r') as file:
        for line in file:
            condition = line[35:37].strip()
            crash_id = line[:31].strip()
            if condition and int(condition) == 2:
                injuries.add(crash_id)
            if condition and int(condition) == 1:
                deaths.add(crash_id)
    
    with open(f"{year}/NewJersey{year}Occupants.txt", 'r') as file:
        for line in file:
            condition = line[38:40].strip()
            crash_id = line[:31].strip()
            if condition and int(condition) == 2:
                injuries.add(crash_id)
            if condition and int(condition) == 1:
                deaths.add(crash_id)
    # Create a set of crashes that contain a serious injury but no deaths
    injurycrashes = injuries - deaths

    with open(f"{year}/crash{year}.csv", "w") as f:
        f.write("id,dt,lat,lon,city,county,street_1,street_2,crash_type,death_count,severity\n")
        with open(f'{year}/NewJersey{year}Accidents.txt', 'r', encoding='latin-1') as file:
            for line in file:
                coords = line[353:370]
                crash_id = line[:31].strip()
                if coords != "       ,        ," and crash_id in injurycrashes:
                    total_killed = int(line[134:136])
                    total_injured = int(line[137:139])
                    severity = line[146:147]
                    date = line[70:80]
                    time = line[84:88].strip()
                    if not time:
                        time = "0000"
                    dt = datetime.strptime(date + " " + time, "%m/%d/%Y %H%M")
                    latitude = line[352:360]
                    longitude = line[361:369]
                    county = line[32:44].strip()
                    city = line[45:69].strip()
                    street_1 = line[160:210].strip()
                    street_2 = line[279:314].strip()
                    crash_type = line[154:156].strip()
                    f.write(f"{crash_id},{dt},{latitude},{longitude},{city},{county},{street_1},{street_2},{crash_type},{total_killed},{severity}\n")
    
    with open(f"{year}/pedestrian{year}.csv", "w") as f:
        f.write("id,bike,age,sex,condition\n")
        with open(f'{year}/NewJersey{year}Pedestrians.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    condition = line[35:37]
                    age = line[84:87].strip()
                    sex = line[88:89]
                    bike = line[197:198]
                    f.write(f"{crash_id},{bike},{age},{sex},{condition}\n")
    
    with open(f"{year}/occupant{year}.csv", "w") as f:
        f.write("id,vehicle_number,position,occupant_number,age,sex,condition\n")
        with open(f'{year}/NewJersey{year}Occupants.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    condition = line[38:40]
                    age = line[47:50].strip()
                    sex = line[51:52]
                    vehicle_number = line[32:34].strip()
                    occupant_number = line[35:37].strip()
                    position = line[41:43]
                    f.write(f"{crash_id},{vehicle_number},{position},{occupant_number},{age},{sex},{condition}\n")
    
    with open(f"{year}/vehicle{year}.csv", "w") as f:
        f.write("id,vehicle_number,year,make,model,hit_run\n")
        with open(f'{year}/NewJersey{year}Vehicles.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    vehicle_number = line[32:34].strip()
                    make = line[43:73].strip()
                    model = line[74:94].replace(",","").strip()
                    yr = line[99:103]
                    hit_run = line[239:240]
                    f.write(f"{crash_id},{vehicle_number},{yr},{make},{model},{hit_run}\n")
    
    with open(f"{year}/driver{year}.csv", "w") as f:
        f.write("id,vehicle_number,charge\n")
        with open(f'{year}/NewJersey{year}Drivers.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    vehicle_number = line[32:34].strip()
                    violation = line[95:125]
                    f.write(f"{crash_id},{vehicle_number},{violation}\n")

# %%
for year in range(2017,2019):
    # EXTRACT DATA FROM ZIPFILES
    # extract_path = f"{year}"
    # zip_path = f"NewJersey{year}Accidents.zip"
    # with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    #     zip_ref.extractall(extract_path)
    # zip_path = f"NewJersey{year}Vehicles.zip"
    # with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    #     zip_ref.extractall(extract_path)
    # zip_path = f"NewJersey{year}Drivers.zip"
    # with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    #     zip_ref.extractall(extract_path)
    # zip_path = f"NewJersey{year}Occupants.zip"
    # with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    #     zip_ref.extractall(extract_path)
    # zip_path = f"NewJersey{year}Pedestrians.zip"
    # with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    #     zip_ref.extractall(extract_path)
    # Comb person-level CSVs to get all injury crash IDs
    injuries = set()
    deaths = set()
    with open(f"{year}/NewJersey{year}Pedestrians.txt", 'r') as file:
        for line in file:
            condition = line[35:37].strip()
            crash_id = line[:31].strip()
            if condition and int(condition) == 2:
                injuries.add(crash_id)
            if condition and int(condition) == 1:
                deaths.add(crash_id)
    
    with open(f"{year}/NewJersey{year}Occupants.txt", 'r') as file:
        for line in file:
            condition = line[38:40].strip()
            crash_id = line[:31].strip()
            if condition and int(condition) == 2:
                injuries.add(crash_id)
            if condition and int(condition) == 1:
                deaths.add(crash_id)
    # Create a set of crashes that contain a serious injury but no deaths
    injurycrashes = injuries - deaths

    with open(f"{year}/crash{year}.csv", "w") as f:
        f.write("id,dt,lat,lon,city,county,street_1,street_2,crash_type,death_count,severity\n")
        with open(f'{year}/NewJersey{year}Accidents.txt', 'r', encoding='latin-1') as file:
            for line in file:
                coords = line[361:380]
                crash_id = line[:31].strip()
                if coords != "         ,         " and crash_id in injurycrashes:
                    total_killed = int(line[134:136])
                    severity = line[146:147]
                    date = line[70:80]
                    time = line[84:88].strip()
                    if not time:
                        time = "0000"
                    dt = datetime.strptime(date + " " + time, "%m/%d/%Y %H%M")
                    latitude = line[361:370]
                    longitude = line[371:380]
                    county = line[32:44].strip()
                    city = line[45:69].strip()
                    street_1 = line[160:210].strip()
                    street_2 = line[285:320].strip()
                    crash_type = line[154:156].strip()
                    f.write(f"{crash_id},{dt},{latitude},{longitude},{city},{county},{street_1},{street_2},{crash_type},{total_killed},{severity}\n")
    
    with open(f"{year}/pedestrian{year}.csv", "w") as f:
        f.write("id,bike,age,sex,condition\n")
        with open(f'{year}/NewJersey{year}Pedestrians.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    condition = line[35:37]
                    age = line[84:87].strip()
                    sex = line[88:89]
                    bike = line[387:388]
                    f.write(f"{crash_id},{bike},{age},{sex},{condition}\n")
    
    with open(f"{year}/occupant{year}.csv", "w") as f:
        f.write("id,vehicle_number,position,occupant_number,age,sex,condition\n")
        with open(f'{year}/NewJersey{year}Occupants.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    condition = line[38:40]
                    age = line[47:50].strip()
                    sex = line[51:52]
                    vehicle_number = line[32:34].strip()
                    occupant_number = line[35:37].strip()
                    position = line[41:43]
                    f.write(f"{crash_id},{vehicle_number},{position},{occupant_number},{age},{sex},{condition}\n")
    
    with open(f"{year}/vehicle{year}.csv", "w") as f:
        f.write("id,vehicle_number,year,make,model,hit_run\n")
        with open(f'{year}/NewJersey{year}Vehicles.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    vehicle_number = line[32:34].strip()
                    make = line[43:73].strip()
                    model = line[74:94].replace(",","").strip()
                    yr = line[99:103]
                    hit_run = line[271:272]
                    f.write(f"{crash_id},{vehicle_number},{yr},{make},{model},{hit_run}\n")
    
    with open(f"{year}/driver{year}.csv", "w") as f:
        f.write("id,vehicle_number,charge\n")
        with open(f'{year}/NewJersey{year}Drivers.txt', 'r', encoding='latin-1') as file:
            for line in file:
                crash_id = line[:31].strip()
                if crash_id in injurycrashes:
                    vehicle_number = line[32:34].strip()
                    violation = line[95:125]
                    f.write(f"{crash_id},{vehicle_number},{violation}\n")

# %%
new_crashes = pd.read_csv("crash.csv")
# Out:
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_90114/2303990507.py:1: DtypeWarning: Columns (0: Driverless Classification, 1: MCMX Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_crashes = pd.read_csv("crash.csv")

# %%
for x in new_crashes.index[1:]:
    crash_id = new_crashes['Crash ID'][x]
    dt = new_crashes['Date & Time of Crash'][x][:-4]
    print(new_crashes['Street Name'][x])
    print(new_crashes['Intersect Street Name'][x])
    print(new_crashes['Latitude'][x])
    print(new_crashes['Longitude'][x])
    print(new_crashes['County'][x])
    print(new_crashes['Municipality'][x])
    print(new_crashes['Crash Type'][x])
    print(dt)
    print("VEHICLE")
    print(new_crashes['Unit ID'][x])
    print(new_crashes['Unit Type'][x])
    print(new_crashes['Vehicle ID'][x])
    print(new_crashes['Vehicle Make'][x])
    # print(new_crashes['Vehicle Model'][x])
    print(new_crashes['Vehicle Type'][x])
    print(new_crashes['Hit and Run'][x])
    print(new_crashes['Citation Issued'][x])
    print("PERSON")
    print(new_crashes['Occupant ID'][x])
    print(new_crashes['Person ID'][x])
    print(new_crashes['Person Type'][x])
    print(new_crashes['Severity Rating (Person)'][x])
    print(new_crashes['Sex'][x])
    print(new_crashes['Age'][x])
    break
# Out:
# Rt 539 (Old York Road)
# Herbert Road
# 40.21016886
# -74.54761731
# Monmouth
# Upper Freehold Twp
# Pedalcyclist
# 2023-08-04T20:17:00
# VEHICLE
# [551,552]
# ["Vehicle","Pedalcyclist"]
# 541
# FORD
# Pick Up
# No
# ["No","No"]
# PERSON
# [null,680]
# [1495,1497]
# ["Driver","Pedalcyclist"]
# ["No Apparent Injury (O)","Suspected Serious Injury (A)"]
# ["Male","Male"]
# [27,50]

# %%
new_crashes[['Unit ID', 'Unit Type', 'Vehicle ID','Vehicle Type','Person ID', 'Person Type','Hit and Run','Citation Issued','Sex',"Age",'Severity Rating (Person)']][2028:2040]
# Out:
#                                       Unit ID  \
# 2028  [10566486,[10566487,10566487,10566487]]
# 2029                      [10566611,10566612]
# 2030                      [10567038,10567039]
# 2031           [[10567154,10567154],10567155]
# 2032                                 10567181
# 2033  [[10567388,10567388,10567388],10567389]
# 2034           [10567578,[10567579,10567579]]
# 2035                      [10567585,10567586]
# 2036  [[10567775,10567775],10567776,10567777]
# 2037  [[10567826,10567826,10567826],10567827]
# 2038                      [10568169,10568170]
# 2039                      [10568407,10568408]
#
#                                Unit Type           Vehicle ID  \
# 2028               ["Vehicle","Vehicle"]  [10404127,10404128]
# 2029            ["Vehicle","Pedestrian"]             10404250
# 2030               ["Vehicle","Vehicle"]  [10404669,10404670]
# 2031               ["Vehicle","Vehicle"]  [10404785,10404786]
# ...

# %%
for x in new_crashes:
    num_person_ids =
# Out:
#   Cell In[92], line 1
#     new_crashes[[new_crashes['Person ID'].size=2]]
#                  ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?

# %%
new_crashes['Unit ID'][2].replace("[","").replace("]","").split(",")
# Out:
# ['569', '569', '569', '569', '570', '570', '570', '570', '570']

# %%
from collections import Counter

# %%
Counter(new_crashes['Unit ID'][2].replace("[","").replace("]","").split(","))
# Out:
# Counter({'570': 5, '569': 4})

# %%
dict(Counter(new_crashes['Unit ID'][2].replace("[","").replace("]","").split(",")))
# Out:
# {'569': 4, '570': 5}

# %%
dict(Counter(new_crashes['Unit ID'][0].replace("[","").replace("]","").split(",")))
# Out:
# {'519': 1}

# %%
for z in dict(Counter(new_crashes['Unit ID'][0].replace("[","").replace("]","").split(","))):
    print(z)
# Out:
# 519

# %%
ROW 71 is all fucked up
ROW 298 is all fucked up
ROW 443 is all fucked up
ROW 447 is all fucked up
ROW 587 is all fucked up
ROW 706 is all fucked up
ROW 770 is all fucked up
ROW 863 is all fucked up
ROW 887 is all fucked up
ROW 888 is all fucked up
