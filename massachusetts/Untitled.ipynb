# %%
import pandas as pd

# %%
# Out:
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/1509545481.py:1: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data16 = pd.read_csv("mass2016.csv")

# %%
import pandas as pd

injury_types = [
    "Non-fatal injury - Incapacitating",
    "Fatal injury (K)",
    "Deceased not caused by crash",
]

# 2016
data16 = pd.read_csv("mass2016.csv")
severe16 = data16[data16["Injury Type"].isin(injury_types)]["Crash Number"]
data16 = data16[data16["Crash Number"].isin(severe16)]

# 2017
data17 = pd.read_csv("mass2017.csv")
severe17 = data17[data17["Injury Type"].isin(injury_types)]["Crash Number"]
data17 = data17[data17["Crash Number"].isin(severe17)]

# 2018
data18 = pd.read_csv("mass2018.csv")
severe18 = data18[data18["Injury Type"].isin(injury_types)]["Crash Number"]
data18 = data18[data18["Crash Number"].isin(severe18)]

# 2019
data19 = pd.read_csv("mass2019.csv")
severe19 = data19[data19["Injury Type"].isin(injury_types)]["Crash Number"]
data19 = data19[data19["Crash Number"].isin(severe19)]

# 2020
data20 = pd.read_csv("mass2020.csv")
severe20 = data20[data20["Injury Type"].isin(injury_types)]["Crash Number"]
data20 = data20[data20["Crash Number"].isin(severe20)]

# 2021
data21 = pd.read_csv("mass2021.csv")
severe21 = data21[data21["Injury Type"].isin(injury_types)]["Crash Number"]
data21 = data21[data21["Crash Number"].isin(severe21)]

# 2022
data22 = pd.read_csv("mass2022.csv")
severe22 = data22[data22["Injury Type"].isin(injury_types)]["Crash Number"]
data22 = data22[data22["Crash Number"].isin(severe22)]

# 2023
data23 = pd.read_csv("mass2023.csv")
severe23 = data23[data23["Injury Type"].isin(injury_types)]["Crash Number"]
data23 = data23[data23["Crash Number"].isin(severe23)]

# 2024
data24 = pd.read_csv("mass2024.csv")
severe24 = data24[data24["Injury Type"].isin(injury_types)]["Crash Number"]
data24 = data24[data24["Crash Number"].isin(severe24)]

# 2025
data25 = pd.read_csv("mass2025.csv")
severe25 = data25[data25["Injury Type"].isin(injury_types)]["Crash Number"]
data25 = data25[data25["Crash Number"].isin(severe25)]

# 2026
data26 = pd.read_csv("mass2026.csv")
severe26 = data26[data26["Injury Type"].isin(injury_types)]["Crash Number"]
data26 = data26[data26["Crash Number"].isin(severe26)]

# Combine all 11 years into a single DataFrame
mass = pd.concat(
    [
        data16,
        data17,
        data18,
        data19,
        data20,
        data21,
        data22,
        data23,
        data24,
        data25,
        data26,
    ],
    axis=0,
    ignore_index=True,
)

# Export combined output
mass.to_csv("mass.csv", index=False)
# Out:
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:10: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data16 = pd.read_csv("mass2016.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:15: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data17 = pd.read_csv("mass2017.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:20: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data18 = pd.read_csv("mass2018.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:25: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data19 = pd.read_csv("mass2019.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:30: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data20 = pd.read_csv("mass2020.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:35: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data21 = pd.read_csv("mass2021.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:40: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data22 = pd.read_csv("mass2022.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:45: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data23 = pd.read_csv("mass2023.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:50: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data24 = pd.read_csv("mass2024.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:55: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data25 = pd.read_csv("mass2025.csv")
# /var/folders/0r/74g1680s6rz9r8mbc5tx0_0c0000gn/T/ipykernel_12088/791403951.py:60: DtypeWarning: Columns (0: Crash Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data26 = pd.read_csv("mass2026.csv")

# %%
data16[data16['Crash Number'].isin(severe_crashes)]
# Out:
#       Crash Number City Town Name  Crash Date Crash Status Crash Time  \
# 1          4128599         NATICK  01/02/2016       Closed   12:39 PM
# 2          4128599         NATICK  01/02/2016       Closed   12:39 PM
# 3          4128599         NATICK  01/02/2016       Closed   12:39 PM
# 39         4129506      ATTLEBORO  01/02/2016       Closed    4:39 PM
# 40         4129506      ATTLEBORO  01/02/2016       Closed    4:39 PM
# ...            ...            ...         ...          ...        ...
# 65502      4278540        CHELSEA  10/30/2016       Closed    6:40 PM
# 65503      4278540        CHELSEA  10/30/2016       Closed    6:40 PM
# 65507      4278547        CHELSEA  11/02/2016       Closed   10:53 AM
# 65508      4278547        CHELSEA  11/02/2016       Closed   10:53 AM
# 65534      4278609         MARION  11/06/2016       Closed    2:15 AM
#
#        Number of Vehicles  Total Fatalities County Name     Hit and Run  \
# 1                     1.0               0.0   MIDDLESEX  No hit and run
# 2                     1.0               0.0   MIDDLESEX  No hit and run
# 3                     1.0               0.0   MIDDLESEX  No hit and run
# 39                    2.0               0.0     BRISTOL  No hit and run
# 40                    2.0               0.0     BRISTOL  No hit and run
# ...                   ...               ...         ...             ...
# 65502                 2.0               0.0     SUFFOLK  No hit and run
# 65503                 2.0               0.0     SUFFOLK  No hit and run
# 65507                 1.0               0.0     SUFFOLK  No hit and run
# 65508                 1.0               0.0     SUFFOLK  No hit and run
# 65534                 1.0               0.0    PLYMOUTH  No hit and run
#
#                Vehicle Sequence of Events (All Vehicles)  ...  Vehicle Make  \
# 1                         V1:(Collision with pedestrian)  ...           GMC
# 2                         V1:(Collision with pedestrian)  ...           GMC
# 3                         V1:(Collision with pedestrian)  ...           NaN
# 39      V1:(Collision with motor vehicle in traffic),...  ...          HYUN
# 40      V1:(Collision with motor vehicle in traffic),...  ...          HYUN
# ...                                                  ...  ...           ...
# 65502   V1:(Collision with motor vehicle in traffic) ...  ...           NaN
# 65503   V1:(Collision with motor vehicle in traffic) ...  ...          TOYT
# 65507                     V1:(Collision with pedestrian)  ...          MITS
# 65508                     V1:(Collision with pedestrian)  ...           NaN
# 65534   V1:(Collision with motor vehicle in traffic),...  ...        TOYOTA
#
#        Vehicle Model Vehicle Model Year Driver Violation Code Person Number  \
# 1                NaN             2005.0       (89 11),(90 24)           1.0
# 2                NaN             2005.0                   NaN           2.0
# 3                NaN                NaN                   NaN           3.0
# 39               NaN             2004.0               (89/4A)           1.0
# 40               NaN             2004.0                   NaN           2.0
# ...              ...                ...                   ...           ...
# 65502            NaN                NaN                   NaN           1.0
# 65503         COROLL             2010.0                   NaN           2.0
# 65507            NaN             2004.0                   NaN           1.0
# 65508            NaN                NaN                   NaN           2.0
# 65534            NaN             2004.0                   NaN           1.0
#
#         Age Ejected Description                        Injury Type  \
# 1      89.0         Not ejected                          No injury
# 2      83.0         Not ejected                          No injury
# 3      71.0                 NaN  Non-fatal injury - Incapacitating
# 39     20.0         Not ejected                          No injury
# 40     22.0         Not ejected                          No injury
# ...     ...                 ...                                ...
# 65502  28.0     Totally ejected  Non-fatal injury - Incapacitating
# 65503  24.0         Not ejected                          No injury
# 65507  51.0         Not ejected                          No injury
# 65508  37.0                 NaN  Non-fatal injury - Incapacitating
# 65534  29.0         Not ejected  Non-fatal injury - Incapacitating
#
#            Person Type         Sex
# 1               Driver    M - Male
# 2            Passenger  F - Female
# 3      Vulnerable User    M - Male
# 39              Driver    M - Male
# 40           Passenger    M - Male
# ...                ...         ...
# 65502           Driver    M - Male
# 65503           Driver    M - Male
# 65507           Driver    M - Male
# 65508  Vulnerable User  F - Female
# 65534           Driver  F - Female
#
# [4996 rows x 26 columns]

# %%
data16['Crash Number'][x]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data16['Crash Number'][x]
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.6_2/libexec/lib/python3.14/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.6_2/libexec/lib/python3.14/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.6_2/libexec/lib/python3.14/site-packages/pandas/core/indexes/range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'Crash Number'
