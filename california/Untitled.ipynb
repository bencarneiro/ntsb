# %%
import pandas as pd
import os
pd.set_option('display.max_columns', None)

# %%
collisions = pd.read_csv("early_data/collisions.csv")
parties = pd.read_csv("early_data/parties.csv")
victims = pd.read_csv("early_data/victims.csv")

# %%
collisions.sort_values("case_id", ascending=False).head(300)
# Out:
#              case_id    primary_road   secondary_road collision_date  \
# 174526  9.870011e+18         LEAR AV       IRONAGE RD     2001-12-08
# 174525  9.870011e+18  PIONEERTOWN RD    SUNNYSLOPE DR     2001-12-01
# 174524  9.870011e+18    ALTA LOMA DR          ALTA AV     2001-12-01
# 174523  9.870011e+18    PIPES CYN RD           RT 247     2001-10-31
# 174522  9.870011e+18           RT 62    SADDLEBACK RD     2001-10-05
# ...              ...             ...              ...            ...
# 174231  9.850010e+18   WILSON RCH RD           AVENAL     2001-01-09
# 174230  9.840011e+18    RT 15 NBON/R  HIDDEN VLY PKWY     2001-12-28
# 174229  9.840011e+18      MENIFEE RD      MOUNTAIN AV     2001-12-28
# 174228  9.840011e+18           RT 60        VALLEY WY     2001-12-26
# 174227  9.840011e+18      ROYALTY RD    TOURNAMENT DR     2001-12-25
#
#        collision_time county_location type_of_collision  killed_victims  \
# ...

# %%
type(collisions['collision_time'][1])
# Out:
# str

# %%
parties['party_type'].unique()
# Out:
# array(['driver', 'pedestrian', 'bicyclist', 'parked vehicle', 'other',
#        nan], dtype=object)

# %%
victims['victim_degree_of_injury'].unique()
# Out:
# array(['severe injury', 'no injury', 'killed', 'other visible injury',
#        'complaint of pain'], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17155/788960195.py in <module>
# ----> 1 for x, y in victims['victim_degree_of_injury'].value_counts():
#       2     print(x)
#       3     print(y)
#
# TypeError: cannot unpack non-iterable int object

# %%
crashes['POINT_Y'][2995]
# Out:
# nan

# %%
victims['VICTIM_DEGREE_OF_INJURY'].unique()
# Out:
# array([1, 0, 2, 5, 6, 7, 4, 3])

# %%
test = crashes[crashes['COLLISION_TIME']>=2400]
for x in test.index:
    print(x)
# Out:
# 54
# 127
# 163
# 230
# 331
# 396
# 436
# 621
# 705
# 911
# 1199
# 1440
# 1459
# 1603
# 1638
# 1642
# 1774
# 1852
# 1899
# 2142
# 2563
# 2599
# 2642
# 2800
# 2827

# %%
crashes[pd.isnull(crashes["LATITUDE"])]
# Out:
#       CASE_ID  ACCIDENT_YEAR   PROC_DATE  JURIS COLLISION_DATE  \
# 1     7136447           2015  2015-12-15   5407     2015-11-20
# 14    6498499           2014  2016-04-08   5406     2014-04-16
# 17    8078519           2016  2016-07-18   5407     2016-06-02
# 18    8939309           2019  2021-05-28   5406     2019-08-24
# 26    9083136           2020  2020-07-07   5406     2020-03-17
# ...       ...            ...         ...    ...            ...
# 2988  9753280           2024  2024-12-06   5405     2024-10-13
# 2991  9781116           2024  2025-02-07   5401     2024-11-27
# 2993  9793609           2025  2025-03-20   5407     2025-02-11
# 2994  9807416           2025  2025-05-29   5403     2025-04-14
# 2995  9830173           2025  2025-07-30   5401     2025-04-13
#
#       COLLISION_TIME OFFICER_ID REPORTING_DISTRICT  DAY_OF_WEEK  CHP_SHIFT  \
# 1               1450       M222                480            5          5
# ...

# %%
parties[pd.isnull(parties['STWD_VEHICLE_TYPE'])]
# Out:
# Empty DataFrame
# Columns: [CASE_ID, PARTY_NUMBER, PARTY_TYPE, AT_FAULT, PARTY_SEX, PARTY_AGE, PARTY_SOBRIETY, PARTY_DRUG_PHYSICAL, DIR_OF_TRAVEL, PARTY_SAFETY_EQUIP_1, PARTY_SAFETY_EQUIP_2, FINAN_RESPONS, SP_INFO_1, SP_INFO_2, SP_INFO_3, OAF_VIOLATION_CODE, OAF_VIOL_CAT, OAF_VIOL_SECTION, OAF_VIOLATION_SUFFIX, OAF_1, OAF_2, PARTY_NUMBER_KILLED, PARTY_NUMBER_INJURED, MOVE_PRE_ACC, VEHICLE_YEAR, VEHICLE_MAKE, STWD_VEHICLE_TYPE, CHP_VEH_TYPE_TOWING, CHP_VEH_TYPE_TOWED, RACE, INATTENTION, SPECIAL_INFO_F, SPECIAL_INFO_G, ACCIDENT_YEAR]
# Index: []

# %%
parties
# Out:
#       CASE_ID  PARTY_NUMBER PARTY_TYPE AT_FAULT PARTY_SEX  PARTY_AGE  \
# 0     6292423             1          4        Y         M         67
# 1     6292423             2          1        N         F         40
# 2     9236533             1          1        N         M         40
# 3     9378016             1          1        Y         M         51
# 4     9378016             2          1        N         F         19
# ...       ...           ...        ...      ...       ...        ...
# 5381  9807416             2          1        N         M         29
# 5382  9830173             1          4        Y         M         20
# 5383  9830173             2          1        N         M         38
# 5384  9871287             1          4        Y         F         40
# 5385  9871287             2          1        N         M         78
#
#      PARTY_SOBRIETY PARTY_DRUG_PHYSICAL DIR_OF_TRAVEL PARTY_SAFETY_EQUIP_1  \
# ...

# %%
parties
# Out:
#              case_id  party_number party_type  party_age party_sex  \
# 0       3.899490e+06             1     driver       49.0      male
# 1       3.899490e+06             2     driver       64.0    female
# 2       3.899490e+06             3     driver       46.0      male
# 3       3.899490e+06             4     driver       45.0      male
# 4       3.982906e+06             1     driver       67.0    female
# ...              ...           ...        ...        ...       ...
# 321996  9.870011e+18             1     driver       58.0      male
# 321997  9.870011e+18             2     driver       55.0      male
# 321998  9.870011e+18             1     driver       46.0    female
# 321999  9.870011e+18             2     driver        NaN    female
# 322000  9.870011e+18             3     driver       53.0      male
#
#         vehicle_year vehicle_make statewide_vehicle_type
# 0             1990.0     plymouth          passenger car
# ...

# %%
victims.head(20)
# Out:
#      CASE_ID  PARTY_NUMBER  VICTIM_NUMBER  VICTIM_ROLE VICTIM_SEX  VICTIM_AGE  \
# 0    6292423             1              1            4          M          67
# 1    6292423             2              1            2          F          13
# 2    6292423             2              2            2          M           8
# 3    6292423             2              3            2          F           9
# 4    6292423             2              4            2          M          11
# 5    7136447             1              1            2          M          11
# 6    9236533             1              1            2          M          32
# 7    9236533             1              2            2          M          28
# 8    9378016             1              1            2          M          25
# 9    9378016             2              1            2          F          52
# 10   9378016             5              1            2          F          31
# ...

# %%
victims['VICTIM_DEGREE_OF_INJURY'].value_counts()
# Out:
# 5    1852
# 1     893
# 2     881
# 6     609
# 7     535
# 0     357
# 4     329
# 3     286
# Name: VICTIM_DEGREE_OF_INJURY, dtype: int64

# %%
victims[victims['VICTIM_DEGREE_OF_INJURY'] == 5]
# Out:
#        CASE_ID  PARTY_NUMBER  VICTIM_NUMBER  VICTIM_ROLE VICTIM_SEX  \
# 6      9236533             1              1            2          M
# 9      9378016             2              1            2          F
# 13    90666537             1              1            1          F
# 17    92112169             1              4            2          F
# 18    92146473             1              1            1          M
# ...        ...           ...            ...          ...        ...
# 5729   9753280             1              1            1          M
# 5730   9760537             1              1            1          M
# 5731   9760537             2              1            1          F
# 5735   9791865             2              1            1          M
# 5741   9871287             1              1            4          F
#
#       VICTIM_AGE  VICTIM_DEGREE_OF_INJURY VICTIM_SEATING_POSITION  \
# 6             32                        5                       3
# ...

# %%
files = os.listdir("/home/tonydeals/app/ntsb/california")

# Print the files
for file in files:
    if "." in file:
        continue
    crashes_path = f"/home/tonydeals/app/ntsb/california/{file}/Crashes.csv"
    parties_crash = f"/home/tonydeals/app/ntsb/california/{file}/Parties.csv"
    victims_path = f"/home/tonydeals/app/ntsb/california/{file}/Victims.csv"
    crashes = pd.read_csv(crashes_path)
    parties = pd.read_csv(parties_crash)
    victims = pd.read_csv(victims_path)
    break

# %%
class InjuryAccident(models.Model):
    id = models.AutoField(primary_key=True)
    state = models.ForeignKey(State, on_delete= models.DO_NOTHING)
    state_accident_id = models.PositiveBigIntegerField(null=False, blank=False)
    dt = models.DateTimeField(null=False, blank=False)
    latitude = models.DecimalField(null=True, blank=True, decimal_places=7, max_digits=10)
    longitude = models.DecimalField(null=True, blank=True, decimal_places=7, max_digits=10)
    city = models.TextField(null=True, blank=True)
    county = models.TextField(null=True, blank=True)
    street_1 = models.TextField(null=True)
    street_2 = models.TextField(null=True)
    crash_type = models.TextField(null=True, blank=True)
    death_count = models.PositiveSmallIntegerField(null=True, blank=True)
    severe_injury_count = models.PositiveSmallIntegerField(null=True, blank=True)
    def map_link(self):
        return f"<a href='https://www.google.com/maps/search/?api=1&query={self.latitude},{self.longitude}'>({self.latitude}, {self.longitude})</a>"

class InjuryVehicle(models.Model):
    injury_accident = models.ForeignKey(InjuryAccident, on_delete=models.CASCADE)
    vehicle_number = models.PositiveSmallIntegerField(null=False, blank=False)
    make = models.TextField(null=True, blank=True)
    model = models.TextField(null=True, blank=True)
    body_type = models.TextField(null=True, blank=True)
    violation = models.TextField(null=True, blank=True)
    hit_and_run = models.BooleanField(default=False)

class InjuryPerson(models.Model):
    injury_accident = models.ForeignKey(InjuryAccident, on_delete=models.CASCADE)
    injury_vehicle = models.ForeignKey(InjuryVehicle, null=True, blank=True, on_delete = models.CASCADE)
    age = models.PositiveSmallIntegerField(null = True, blank = True)
    #p6 
    sex = models.CharField(max_length=64, null=True, blank=True)
    person_type = models.CharField(max_length=256,null=True, blank=True)
    #p8 injury_severity
    injury_severity_choices = [
        (0, 'No Apparent Injury (O)'),
        (1, 'Possible Injury (C)'),
        (2, 'Suspected Minor Injury (B)'),
        (3, 'Suspected Serious Injury (A)'),
        (4, 'Fatal Injury (K)'),
        (5, 'Injured, Severity Unknown (U) (Since 1978)'),
        (6, 'Died Prior to Crash'),
        (9, 'Unknown/Not Reported')
    ]			
    injury_severity = models.PositiveSmallIntegerField(choices=injury_severity_choices, default=9)

# %% [markdown]
# # get collisions table

# %%
select case_id, primary_road, secondary_road, collision_date, collision_time, county_location, type_of_collision, killed_victims, injured_victims, latitude, longitude from collisions where (collision_date < "2014-01-01") AND (collision_severity = "fatal" or collision_severity = "severe injury");

# %%
select parties.case_id, parties.party_number, parties.party_type, parties.party_age, parties.party_sex, parties.vehicle_year, parties.vehicle_make, parties.statewide_vehicle_type from parties LEFT JOIN collisions on collisions.case_id = parties.case_id where collisions.collision_date < "2014-01-01" and (collisions.collision_severity = "fatal" or collisions.collision_severity = "severe injury");

# %%
select victims.case_id, victims.party_number, victims.victim_degree_of_injury, victims.victim_age, victims.victim_sex, victims.victim_role from victims LEFT JOIN collisions on collisions.case_id = victims.case_id where collisions.collision_date < "2014-01-01" and (collisions.collision_severity = "fatal" or collisions.collision_severity = "severe injury");
